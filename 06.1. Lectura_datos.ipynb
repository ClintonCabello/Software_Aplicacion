# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/ingenieria-de-variables-master/Seccion-02-Tipos-de-Variables/loan.csv")
df
# Out:
#         loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0            5000  36 months     10.65        10.0           RENT     24000.0
# 1            2500  60 months     15.27         0.0           RENT     30000.0
# 2            2400  36 months     15.96        10.0           RENT     12252.0
# 3           10000  36 months     13.49        10.0           RENT     49200.0
# 4            5000  36 months      7.90         3.0           RENT     36000.0
# ...           ...        ...       ...         ...            ...         ...
# 163982      15000  60 months     12.39         3.0       MORTGAGE     45000.0
# 163983      20000  36 months     14.99        10.0            OWN     80000.0
# 163984      12825  36 months     17.14         6.0       MORTGAGE     38000.0
# 163985      27650  60 months     21.99         0.0           RENT     60000.0
# 163986      17000  60 months     15.99        10.0       MORTGAGE     63078.0
#
# ...

# %%
from google.colab import drive
drive.mount('/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Archivos en Pandas

# %%
df2=pd.read_csv("/loan.csv")
df2
# Out:
#         loan_amnt       term  int_rate  emp_length home_ownership  annual_inc  \
# 0            5000  36 months     10.65        10.0           RENT     24000.0
# 1            2500  60 months     15.27         0.0           RENT     30000.0
# 2            2400  36 months     15.96        10.0           RENT     12252.0
# 3           10000  36 months     13.49        10.0           RENT     49200.0
# 4            5000  36 months      7.90         3.0           RENT     36000.0
# ...           ...        ...       ...         ...            ...         ...
# 108714       4000  36 months      7.90         5.0       MORTGAGE     42000.0
# 108715       1500  36 months     18.55         2.0           RENT     28000.0
# 108716       8975  36 months     12.12        10.0           RENT     23355.0
# 108717       8000  36 months     15.31         0.0           RENT     50000.0
# 108718       4500  36 months      6.62         1.0           RENT     46500.0
#
# ...

# %%
# Creamos un DataFrame
datos={  "Nombre" : ['Marcia','Marcos','Luis','Tatiana','Pedro'],
         "Sexo"   : ['Femennino','Masculino','Masculino','Femenino','Masculino'],
         "Edad"   : [23,13,43,17,23],
         "Ciudad" : ['Huancayo','Lima','Trujillo','Arequipa','Ica']}
df3=pd.DataFrame(datos)
df3
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino    23  Huancayo
# 1   Marcos  Masculino    13      Lima
# 2     Luis  Masculino    43  Trujillo
# 3  Tatiana   Femenino    17  Arequipa
# 4    Pedro  Masculino    23       Ica

# %% [markdown]
# ###Exportamos el DataFrame a un archivo de tipo .csv
# * Primero debemos ubicar una carpeta donde guardar el archivo
# * Activamos el googleDrive o enlazamo en el colab
# * Primero vamos a la barra izquieda  y hacemos clik en Archivos
# * Activar Drive
# * Localizar la carpeta en Drive -> MyDrive ->ColabNotebook->dbase
# * Hacer clik en tres puntos y copiar la ruta
# * Lugo copia la tuta y agrega el nombre del archivo y su extension
#
# df.to_csv('/content/drive/MyDrive/Colab Notebooks/dbase/persona.csv')
#
# * se ha guardado el archivo persona.csv en la carpeta dbase. Verificar

# %%
df3.to_csv('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/docente.csv')

# %% [markdown]
# ###Importamos en DataFrame desde un archivo de tipo .csv
# * Copiamos la ruta del archivo, que se encuentra en la carpeta dbase , estando en Mydrive -> dbase -> archivo, clik en los tres puntos y copiar la ruta.

# %%
df=pd.read_csv("/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/docente.csv")
df
# Out:
#    Unnamed: 0   Nombre       Sexo  Edad    Ciudad
# 0           0   Marcia  Femennino    23  Huancayo
# 1           1   Marcos  Masculino    13      Lima
# 2           2     Luis  Masculino    43  Trujillo
# 3           3  Tatiana   Femenino    17  Arequipa
# 4           4    Pedro  Masculino    23       Ica

# %%
# Guardando el archivo con separados '|'

df3.to_csv('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona2.csv',sep='|')

# %%
# Argumento separador de datos
df2=pd.read_csv('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona2.csv',sep='|')
df2
# Out:
#    Unnamed: 0   Nombre       Sexo  Edad    Ciudad
# 0           0   Marcia  Femennino    23  Huancayo
# 1           1   Marcos  Masculino    13      Lima
# 2           2     Luis  Masculino    43  Trujillo
# 3           3  Tatiana   Femenino    17  Arequipa
# 4           4    Pedro  Masculino    23       Ica

# %%
dir='/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona2.csv'

# %%
# Eliminamos la columna de indice
df2=pd.read_csv(dir,sep='|',index_col=0)
df2
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino    23  Huancayo
# 1   Marcos  Masculino    13      Lima
# 2     Luis  Masculino    43  Trujillo
# 3  Tatiana   Femenino    17  Arequipa
# 4    Pedro  Masculino    23       Ica

# %%
# Asignado NaN a algunos valores de la DataFrame
df2=pd.read_csv(dir,sep='|',index_col=0,na_values=[43,23])
df2
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino   NaN  Huancayo
# 1   Marcos  Masculino  13.0      Lima
# 2     Luis  Masculino   NaN  Trujillo
# 3  Tatiana   Femenino  17.0  Arequipa
# 4    Pedro  Masculino   NaN       Ica

# %%
# Argumento separador de datos
df2=pd.read_csv(dir,sep='|',index_col=0,decimal=',')
df2
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino    23  Huancayo
# 1   Marcos  Masculino    13      Lima
# 2     Luis  Masculino    43  Trujillo
# 3  Tatiana   Femenino    17  Arequipa
# 4    Pedro  Masculino    23       Ica

# %%
# Argumento hader que especifica una lista de filas
df2=pd.read_csv(dir,sep='|',index_col=0,header=[0,1,2])
df2
# Out:
#     Nombre       Sexo Edad    Ciudad
# 0   Marcia  Femennino   23  Huancayo
# 1   Marcos  Masculino   13      Lima
# 2     Luis  Masculino   43  Trujillo
# 3  Tatiana   Femenino   17  Arequipa
# 4    Pedro  Masculino   23       Ica

# %%
# Argumento usecols selecciona la que especifica una lista de columnas
df2=pd.read_csv(dir,sep='|',index_col=0,usecols=['Nombre','Sexo'])
df2
# Out:
#               Sexo
# Nombre
# Marcia   Femennino
# Marcos   Masculino
# Luis     Masculino
# Tatiana   Femenino
# Pedro    Masculino

# %%
# Exportamos el DataFrame a un archivo de tipo .excel
df.to_excel('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona3.xlsx')

# %%
dire='/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona3.xlsx'

# %%
# Importamos en DataFrame desde un archivo de tipo .xlsx
df3=pd.read_excel(dire,index_col=0)
df4=df3.iloc[:,1:]
df4
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino    23  Huancayo
# 1   Marcos  Masculino    13      Lima
# 2     Luis  Masculino    43  Trujillo
# 3  Tatiana   Femenino    17  Arequipa
# 4    Pedro  Masculino    23       Ica

# %%
diree='/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase'

# %%
# Exportamos el DataFrame a un archivo de tipo .json
df4.to_json('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona4.json')

# %%
# Importamos en DataFrame desde un archivo de tipo .json
df4=pd.read_json('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona4.json')
df4
# Out:
#     Nombre       Sexo  Edad    Ciudad
# 0   Marcia  Femennino    23  Huancayo
# 1   Marcos  Masculino    13      Lima
# 2     Luis  Masculino    43  Trujillo
# 3  Tatiana   Femenino    17  Arequipa
# 4    Pedro  Masculino    23       Ica

# %%
# Exportamos el DataFrame a un archivo de tipo .Pickle
df.to_pickle('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona.pkl')

# %%
# Importamos en DataFrame desde un archivo de tipo Pikle
df4=pd.read_pickle('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona.pkl')
df4
# Out:
#    Unnamed: 0   Nombre       Sexo  Edad    Ciudad
# 0           0   Marcia  Femennino    23  Huancayo
# 1           1   Marcos  Masculino    13      Lima
# 2           2     Luis  Masculino    43  Trujillo
# 3           3  Tatiana   Femenino    17  Arequipa
# 4           4    Pedro  Masculino    23       Ica

# %%
# Exportamos el DataFrame a un archivo de tipo .Parquet
df.to_parquet('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona.parquet')

# %%
# Importamos en DataFrame desde un archivo de tipo .json
df4=pd.read_parquet('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase06/DataBase/persona.parquet')
df4
# Out:
#    Unnamed: 0   Nombre       Sexo  Edad    Ciudad
# 0           0   Marcia  Femennino    23  Huancayo
# 1           1   Marcos  Masculino    13      Lima
# 2           2     Luis  Masculino    43  Trujillo
# 3           3  Tatiana   Femenino    17  Arequipa
# 4           4    Pedro  Masculino    23       Ica

# %%
# Import pandas desde un url
import seaborn as sns
df2=sns.load_dataset('titanic')
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Despliega las 5 primeras filas
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Despliega las 6 primeras filas
df2.head(6)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True

# %%
#despliega 5 filas aleatoriamente
df2.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 704         0       3    male  26.0      1      0   7.8542        S   Third
# 809         1       1  female  33.0      1      0  53.1000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 17          1       2    male   NaN      0      0  13.0000        S  Second
# 66          1       2  female  29.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 704    man        True  NaN  Southampton    no  False
# 809  woman       False    E  Southampton   yes  False
# 888  woman       False  NaN  Southampton    no  False
# 17     man        True  NaN  Southampton   yes   True
# 66   woman       False    F  Southampton   yes   True

# %%
# despliaga las ultimas 5 filas
df2.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
# Describe los datos
df2.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# describe considerando tods las variable
df2.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
# Devuelve la informacion sobre el data frame
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Devuelve la cantidad
df2.shape
# Out:
# (891, 15)

# %%
# el tamano de registros
df2.size
# Out:
# 13365

# %%
# Devuelve las columnas
df2.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# devuelve los tipos
df2.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# Renombrar los nombres de las filas y columnas
print(df2.reindex(index=[1,2,3,4],columns=['name','id']))
# Out:
#        name   id
# 1    Aarhus    2
# 2      Abee    6
# 3  Acapulco   10
# 4   Achiras  370
