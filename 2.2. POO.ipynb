# %% [markdown]
# #Programación Orientada a Objetos
#
# La Programación Orientada a Objetos (POO u OOP según sus siglas en inglés) es un paradigma de programación que usa objetos y sus interacciones para diseñar aplicaciones y programas de computadora. Está basado en varias técnicas, incluyendo herencia, modularidad, polimorfismo, y encapsulamiento. Su uso se popularizó a principios de la década de 1990. Actualmente son muchos los lenguajes de programación que soportan la orientación a objetos.
#
# La programación Orientada a objetos (POO) es una forma especial de programar, más cercana a como se expresan las cosas en la vida real que otros tipos de programación.
#
# La POO es un paradigma de la programación de computadores; esto hace referencia al conjunto de teorías, estándares, modelos y métodos que permiten organizar el conocimiento, proporcionando un medio bien definido para visualizar el dominio del problema e implementar en un lenguaje de programación la solución a ese problema.

# %% [markdown]
# ![maxresdefault.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Clase de Programación Orientada a Objetos**
#
# [CLASE de POO](https://www.youtube.com/watch?v=AAKoccH230Y)

# %% [markdown]
# # Conceptos Fundamentales de la POO
#
# La programación orientada a objetos es una forma de programar que trata de encontrar una solución a estos problemas. Introduce nuevos conceptos, que superan y amplían conceptos antiguos ya conocidos. Entre ellos destacan los siguientes:
#
# ###**Clase**
# Es una plantilla o modelo que contiene atributos y métodos
#
# ### **Objeto**
# Un objeto es una instancia de una clase. Entidad provista de un conjunto de propiedades o atributos (datos) y de comportamiento o funcionalidad (métodos).
#
# ### **Método**
#
#
# Es una función, por lo tanto es la funcionalidad asociado a un objeto (o a una clase de objetos). Desde el punto de vista del comportamiento, es lo que el objeto puede hacer.
#
# ## **Mensaje**
# Una comunicación dirigida a un objeto, que le ordena que ejecute uno de sus métodos con ciertos parámetros asociados al evento que lo generó
#
# ### **Comportamiento**
#
# Está definido por los métodos o mensajes a los que sabe responder dicho objeto, es decir, qué operaciones se pueden realizar con él.
#
# ### **Evento**
# Es un suceso en el sistema (tal como una interacción del usuario con la máquina, o un mensaje enviado por un objeto). El sistema maneja el evento enviando el mensaje adecuado al objeto pertinente. También se puede definir como evento la reacción que puede desencadenar un objeto; es decir, la acción que genera.
#
# ###**Atributos**
# ###**Características que tiene la clase**
#
# ###**Propiedad o atributo**
# Contenedor de un tipo de datos asociados a un objeto (o a una clase de objetos), que hace los datos visibles desde fuera del objeto y esto se define como sus características predeterminadas, y cuyo valor puede ser alterado por la ejecución de algún método.
#
# ###**Estado interno**
# Es una variable que se declara privada, que puede ser únicamente accedida y alterada por un método del objeto, y que se utiliza para indicar distintas situaciones posibles para el objeto (o clase de objetos). No es visible al programador que maneja una instancia de la clase.
#
# ###**Componentes de un objeto**
# Atributos, identidad, relaciones y métodos.
#
# ###**Identificación de un objeto**
# Un objeto se representa por medio de una tabla o entidad que esté compuesta por sus atributos y funciones correspondientes.

# %% [markdown]
# # Clases e Instancias
#
# Una clase es una plantilla un modelo que permite crear objetos de caracteristica común, se define anteponiendo la palabra reservada class

# %%
# Ejemplo 01
class Cliente:
    pass

# %% [markdown]
# Ejemplos de nombre de clases:
#
# >Alumno \\
# >Profesor
# >Cliente \\
# >Persona \\
# >Asignatura
# >Parque
# >Cuenta

# %%
Cliente
# Out:
# __main__.Cliente

# %% [markdown]
# Definamos el primer objeto cliente, el objeto está vacio, al visualizar se observa la dirección de memoria del computador.

# %%
ob1=Cliente()
print(ob1)

# %% [markdown]
# Ahora asignamos un atributo nombre con su valor correspondiente "Tania" y la edad 23

# %%
ob1.nombre="Tania"
ob1.edad=23

# %% [markdown]
# Al mostrar los datos del objeto de tiene:

# %%
print(ob1.nombre,"  ",ob1.edad)
# Out:
# Tania    23

# %% [markdown]
# Vamos a crear un nuevo objeto de la clase Cliente

# %%
ob2=Cliente()

# %% [markdown]
# Nuevamente el segundo objeto está vacio, al mostrar el dicho objeto se observa la dirección donde se encuentra

# %%
print(ob2)

# %% [markdown]
# Asignando valor al segundo objeto

# %%
ob2.nombre="Juan"
ob2.edad=78

# %% [markdown]
# Mostrando los datos se tiene:

# %%
print(ob2.nombre," ",ob2.edad)
# Out:
# Juan   78

# %% [markdown]
# Es importante entender qie las clase se crean en tiempo de ejecución, cuando la instrucción **class** es ejecutada, el código contenido dentro de la clase se ejecuta inmediatamente en el momento de su definicón

# %%
import sys
class Profesor:
    print("Python")
    print(sys.platform)
# Out:
# Python
# linux

# %%
ob1=Profesor()
ob1

# %% [markdown]
# # Variables gloales y variables locales

# %%
# Variable global
b=10
class Caja:
    print(b)
class Libro:
    print(2*b)
# Out:
# 10
# 20

# %%
# declarando una variable global
a=99
class Foo:
    print(a)
# Out:
# 99

# %%
# declaración de una variable local
class Caja:
    a=999
    print(a)
# Out:
# 999

# %% [markdown]
# ### Las clases tiene una serie de atributos denominados **atributos especiales** o **atributos magicos**, que enpiesan y acaban con dos guiones bajos. por ejemplo \_\_name\_\_ es un atributo especial al cual se le asigna el nombre de la etiqueta utilizando en la definición de la clase.

# %%
class Caja:
    a=2000
    print(a)
# Out:
# 2000

# %%
Caja.__name__
# Out:
# 'Caja'

# %% [markdown]
# El atributo  \_\_module\_\_  tambien es especial y se refiere al nombre del módulo en el cual se define la clase

# %%
Caja.__module__
# Out:
# '__main__'

# %% [markdown]
# # Atributos de una clase

# %% [markdown]
# Las clase se definen utilizando etiquetas que enpiesan con la letra mayuscula
#
# Las clase se utilizan para definir tipos de datos, los objetos creados mediante una clase se denominan instancias de clase

# %%
# Ejemplo de instancia de una clase
class Persona:
    # Atributos
    nombre=" "
    edad=0
    sexo=" "

# %%
p1=Persona()

# %%
p1.nombre="Marcia"
p1.edad=23
p1.sexo="Femenino"

# %%
print(p1.nombre," ",p1.edad," ",p1.sexo)
# Out:
# Marcia   23   Femenino

# %% [markdown]
# Ejemplo. Un programa que implementa la clase cicunferencia

# %%
from math import pi
class Circunferencia:
    # Atributo
    radio=0
    # Metodos
    def ingresar(self,radio):
        self.radio=radio
    def calcular_volumen(self):
        volumen=pi*self.radio**2
        return volumen
    def mostrar_volumen(self):
        print("El volumen es:",round(self.calcular_volumen(),2))
ob1=Circunferencia()
ob1.ingresar(3)
ob1.mostrar_volumen()
# Out:
# El volumen es: 28.27

# %% [markdown]
# Ejemplo. Programa que calcula el área del triángulo rectángulo

# %%
class Triangulo:
    # Atributo de la clase
    base=0
    altura=0
    # Métodos de la calse
    def ingresar(self,base,altura):
        self.base=base
        self.altura=altura
    def calcular_area(self):
        area=self.base*self.altura/2
        print(f"El área del triángulo es: {area}")

# %%
obj1=Triangulo()
obj1.ingresar(5,3)
obj1.calcular_area()
# Out:
# El área del triángulo es: 7.5

# %% [markdown]
# Ejemplo. Calcula el volumen de un cilindro

# %%
from math import pi
class Cilindro:
    #Atributo
    radio=0
    altura=0
    #Métodos
    def ingresar(self, radio,altura):
        self.radio=radio
        self.altura=altura
    def calcular_volumen(self):
        volumen=pi*self.radio**2*self.altura
        return volumen
    def mostrar(self):
        print("El volumen es: {:.2f}".format(self.calcular_volumen()))

# %%
obt=Cilindro()
obt.ingresar(2,3)
obt.mostrar()
# Out:
# El volumen es: 37.70

# %%
class cuadrado:
    #atributos comunes
    _dimension = '2D'
    _vertices = 4

    def __init__(self, lado, color):
        #atributos independientes
        self._lado = lado
        self._color = color

# %%
class cuadrado:

    # la función __init__ permite la construcción de objetos.
    def __init__(self, lado):
        # el argumento self hace referencia al objeto en sí (a sí mismo)
        self._lado = lado
        # objeto.atributo
        # se define el atributo lado

# %%
type(obt)
# Out:
# __main__.Cilindro

# %%
isinstance(obt,Cilindro)
# Out:
# True

# %%
isinstance(obt,Triangulo)
# Out:
# False

# %% [markdown]
# creamos dos instancias de la clase list

# %%
lista1=[1,2,3,4]
lista2=[4,5,6,7]

# %% [markdown]
# Vamos a comprobar que es de tipo lista

# %%
lista1.__class__
# Out:
# list

# %%
lista2.__class__
# Out:
# list

# %%
type(lista1)
# Out:
# list

# %%
type(lista2)
# Out:
# list

# %% [markdown]
# Ademas podemos utilizar la función integrada sinstance() para saber si un objeto es una instancia de una determinada clase

# %%
mylist=[2,4,5,6]
isinstance(mylist,list)
# Out:
# True

# %%
class Foo:
    pass

# %% [markdown]
# La clase es un objeto llamable

# %%
callable(Foo)
# Out:
# True

# %%
# cuando se llama una clase se crea una instancia
f=Foo()
g=Foo()

# %%
type(f), type(g)
# Out:
# (__main__.Foo, __main__.Foo)

# %%
obj1.__class__
# Out:
# __main__.Triangulo

# %% [markdown]
# La clase Foo esta definida en el modulo \_\_main\_\_

# %%
type(Foo), Foo.__class__
# Out:
# (type, type)

# %% [markdown]
# # El parametro self

# %% [markdown]
# Los atributos pueden ser llamables o no, si lo son se llama metodos
# Por ejemplo la siguiente clase, tiene un atributo "a" que no es llamable y un metodo

# %%
class Foo:
    a=33
    def foo_method(self):
        print(id(self))

# %%
Foo.a
# Out:
# 33

# %%
obj=Foo()
obj.a
# Out:
# 33

# %%
obj.foo_method()
# Out:
# 139673567387344

# %%
mylist=[2,3,4,5]
Foo.foo_method(mylist)
# Out:
# 139673567552368

# %%
id(mylist)
# Out:
# 139673567552368

# %%
x=30
id(x)
# Out:
# 11256992

# %%
y=30
id(y)
# Out:
# 11256992

# %%
z=30
id(z)
# Out:
# 11256992

# %% [markdown]
# Normalmente los métodos ejecutan operaciones en instancia de clases, por lo que generalmente reciben la instancia como un argumento y luego la procesan.

# %%
class Foo:
    a=33
    def foo_method(self):
        print(id(self))

# %%
Foo()

# %%
a=Foo()
a

# %% [markdown]
# el objeto a muestra la dirección de memoria también representado por "self"

# %%
f=Foo()
Foo.foo_method(f)
# Out:
# 139673567407760

# %% [markdown]
# pasar la instancia al método es la operación que se basa la programación orientada a objetos

# %%
f.foo_method()
# Out:
# 139673567407760

# %% [markdown]
# Este comportamiento no siempre es asi, por que existe un tipo
# de método denominado metodo de clase, a las cuales siempre se pasa la clase como primer argumento

# %%
class Foo:
    def foo_method(self):
        print('python')

# %%
Foo.foo_method()
# Out:
# python

# %%
f=Foo()

# %%
f.foo_method()
# Out:
# python

# %% [markdown]
# La etiqueta especial \_\_class\_\_ si se utiliza dentro de un metodo, se refiere a la clase

# %%
class Foo:
    def foo(self):
        print(__class__)

# %%
Foo.foo()
# Out:
# <class '__main__.Foo'>

# %%
ob=Foo()
ob.foo()
# Out:
# <class '__main__.Foo'>

# %% [markdown]
# # Atributo de una clase y de instancia
#
# En cuanto a su ambito de visibilidad, los atributos pueden ser de clase o de instancia
# Trataremos de aclarar este concepto, las asignaciones realizadas fiera de los metodos

# %%
class Foo:
    a=33
    def foo_method(self,obj):
        Foo.a=obj

# %%
Foo.a
# Out:
# 33

# %%
f=Foo()
g=Foo()

# %%
id(f),id(g)
# Out:
# (140366101510992, 140366101510928)

# %%
f.a, g.a
# Out:
# (33, 33)

# %%
id(f.a), id(g.a)
# Out:
# (11257088, 11257088)

# %%
f.foo_method(100)
f.a
# Out:
# 100

# %%
 id(f.a)
# Out:
# 11259232

# %%
Foo.a
# Out:
# 100

# %% [markdown]
# Esto significa que, si una clase o una instancia modifica un atributo de clase, dicho cambio se ve tanto desde la clase como desde sus otras instancias

# %%
Foo.a='Python'

# %%
f.a, g.a
# Out:
# ('Python', 'Python')

# %%
f.foo_method([1,2,3])

# %%
g.a
# Out:
# [1, 2, 3]

# %%
f.a
# Out:
# [1, 2, 3]

# %% [markdown]
# Los métodos tambien son atributos de clase, en cuanto definimos en el nivel superior de la clase, por lo que son comaprtidos por todas las instancias.

# %%
def foo(self):
    print(id(self))

# %%
Foo.foo_method=foo
f.foo_method()
# Out:
# 140366101510992

# %%
g.foo_method()
# Out:
# 140366101510928

# %% [markdown]
# Las asignaciones realizadas a etiquetas calificadas mediante la instancia crean atributos de instancias
# es decir, exclusivos a esas instancias y no compartidos ni con otras instancias ni menos aun con la clase

# %%
class Foo:
    pass
f=Foo()
g=Foo()

# %%
f.b=33

# %%
hasattr(Foo,'a')
# Out:
# False

# %%
hasattr(g,'a')
# Out:
# False

# %%
hasattr(f,'b')
# Out:
# True

# %%
g.m=200

# %%
hasattr(g,'m')
# Out:
# True

# %%
hasattr(f,'m')
# Out:
# False

# %% [markdown]
# Las asignaciones realizadas a etiquetas calificadas mediante la clase crean atributos de clase compartidos por tadas las instancias

# %%
class Foo:
    a=33

# %%
f=Foo()
g=Foo()

# %%
f.a, g.a
# Out:
# (33, 33)

# %%
Foo.b=100
f.b, g.b
# Out:
# (100, 100)

# %% [markdown]
# si dentro del un método queremos crear un atributo de instancia, necesitamos calificar el atributo
# mediante el parametro que hace referencia a la instancia

# %%
class Foo:
    a=33
    def foo_method(self,x):
        self.b=x

# %%
f=Foo()
g=Foo()

# %%
hasattr(Foo,'b'),hasattr(f,'b'),hasattr(g,'b')
# Out:
# (False, False, False)

# %%
f.foo_method('fffff')

# %%
hasattr(Foo,'b'),hasattr(f,'b'),hasattr(g,'b')
# Out:
# (False, True, False)

# %%
f.b
# Out:
# 'fffff'

# %%
g.foo_method('gggg')

# %%
hasattr(Foo,'b'),hasattr(f,'b'),hasattr(g,'b')
# Out:
# (False, True, True)

# %%
f.b, g.b
# Out:
# ('fffff', 'gggg')

# %%
# Observe la documentación de la biblioteca datetime
import datetime
help(datetime)

# %% [markdown]
# Se observa que datetime incluye las siguientes clases: date, datetime, time, timedelta, tzinfo y timezon. Cada una de ellas tiene una serie de funciones (métodos) que permiten crear un nuevo objeto (el método constructor) y modificarlo. Por ejemplo para crear un nuevo objeto de la clase date, basta con escribir el siguiente código:

# %%
fecha = datetime.date(month=1, day=21, year=2021)
print(fecha)
print(type(fecha))

# %% [markdown]
# La función anterior no es la única que permite crear nuevos objetos, observe que la función "today" también permite crear un objeto de la clase "datetime.date":

# %%
hoy = datetime.date.today()
print(hoy)
print(type(hoy))

# %% [markdown]
# Recuerde que a menudo el nombre de la biblioteca se reemplaza por un alias. Por ejemplo en lugar de escribir:

# %%
import datetime as dt
hoy = dt.date.today()
print(hoy)
print(type(hoy))

# %% [markdown]
# #Clase 03
# # Ambito y espacio de nombres
#
# Los atributos de clase y de instancia son locales

# %%
class Foo:
    a=33
    def foo(self):
        self.b=100

# %%
'a' in globals(), 'foo' in globals(), 'b' in globals()
# Out:
# (False, False, False)

# %%
'a' in vars(Foo), 'foo' in vars(Foo), 'b' in vars(Foo)
# Out:
# (True, True, False)

# %%
f=Foo()
f.foo()

# %%
'a' in vars(f), 'foo' in vars(f), 'b' in vars(f)
# Out:
# (False, False, True)

# %% [markdown]
# El ambito locar a una instancia es embolvente respecto al ambito local de su clase,

# %%
del Foo
f.a
# Out:
# 33

# %%
f.foo
# Out:
# <bound method Foo.foo of <__main__.Foo object at 0x7f8a3e43f2e0>>

# %% [markdown]
# Los atributos calificados mediante la instancia esconden los mismos atributos calificados mediante la clase

# %%
class Foo:
    a=33

# %%
f=Foo()
g=Foo()

# %%
f.a
# Out:
# 33

# %%
f.a='python'
f.a, g.a
# Out:
# ('python', 33)

# %% [markdown]
# El ambito de la clase no es envolvente respecto al ambito local de los metodos

# %%
class Foo:
    c=33
    def foo(self):
        print(self.c)

# %%
ob=Foo()
ob.foo()
# Out:
# 33

# %%
Foo.c
# Out:
# 33

# %% [markdown]
# De hecho los metodos son funciones y como tales resuelven las etiquetas libres en primer lugar en un ambbito emvolvente(ambito de una funcion que los envuelve)

# %%
def foo():
    a='python'
    class Foo:
        def moo():
            print(a)
    return Foo

# %%
F=foo()
F.moo()
# Out:
# python

# %%
class Foo:
    def foo():
        print(d)

# %%
Foo.foo()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-8c3ef17bab13> in <module>
# ----> 1 Foo.foo()
#
# <ipython-input-48-6a2021f6acf3> in foo()
#       1 class Foo:
#       2     def foo():
# ----> 3         print(d)
#
# NameError: name 'd' is not defined

# %%
d=66
Foo.foo()
# Out:
# 66

# %% [markdown]
# asi, si se desea utilizar un atributo dentro de un metodo, es preciso calificarlo con la etiqueta clase

# %%
class Foo:
    c=38
    def foo():
        print(Foo.c)

# %%
Foo.foo()
# Out:
# 38

# %% [markdown]
# cuando dentro de un metodo se realiza una asignación a una etiqueta no calificada, entonce se crea una etiqueta local para el metodo.

# %%
class Foo:
    def foo_method():
        a=99
        print(locals())

# %%
Foo.foo_method()
# Out:
# {'a': 99}

# %%
class Foo:
    a=1
    def foo(self):
        self.b=2
        c=99

# %%
Foo.a
# Out:
# 1

# %%
f=Foo()
f.foo()

# %%
f.b
# Out:
# 2

# %% [markdown]
# El espacio de nombre de la clase asi como el de los modulos se implementa mediante un diccionario asignado a atributo \_\_dict\_\_ de la clase

# %%
class Foo:
    a=44

# %%
'a' in Foo.__dict__
# Out:
# True

# %%
Foo.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'a': 44,
#               '__dict__': <attribute '__dict__' of 'Foo' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Foo' objects>,
#               '__doc__': None})

# %%
Foo.b=33
'b' in Foo.__dict__
# Out:
# True

# %%
Foo.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'a': 44,
#               '__dict__': <attribute '__dict__' of 'Foo' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Foo' objects>,
#               '__doc__': None,
#               'b': 33})

# %% [markdown]
# El espacio de nombre de las instancias se implementa mediante un diccionario

# %%
f=Foo()

# %%
f.__dict__
# Out:
# {}

# %%
f.c=100
f.__dict__
# Out:
# {'c': 100}

# %%
f.c
# Out:
# 100

# %%
f.__dict__['c']
# Out:
# 100

# %%
f.c
# Out:
# 100

# %% [markdown]
# f.__dict__['d']=100
# f.d

# %% [markdown]
# Sin embargo las dos notaciones no son equivalentes

# %%
f.a
# Out:
# 44

# %%
f.__dict__['a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-c297140c9d70> in <module>
# ----> 1 f.__dict__['a']
#
# KeyError: 'a'

# %% [markdown]
# De hecho los atributos de instancias se buscan en primer lugar, en espacio de nombres de la instancia por lo que antes se buscan en f.__dict__

# %%
'a' in f.__dict__
# Out:
# False

# %%
f.__dict__
# Out:
# {'c': 100, 'd': 100}

# %% [markdown]
# cuando un atributo de instancia no se encuentra en su diccionario de atributo, pero resulta que la instancia si que lo tiene, este se busca en el diccionario de atributos de la clase. En nuetsro caso el atributo a no se encuentra en f.__dict__ pero la instancia si tiene atributos

# %%
hasattr(f,'a')
# Out:
# True

# %% [markdown]
# por tanto la busqueda de f.a continua para el atributo a en Foo.__dict__

# %%
'a' in Foo.__dict__
# Out:
# True

# %%
Foo.__dict__['a']
# Out:
# 44

# %% [markdown]
# # Diferencia de implementacion entre el espacio de nombres de clase y de instancia
#
# El espacio de nombres de clase como el de instancia se impleenta mediante un diccionario. El diccionario de los atributos de instancia es un diccionario ordinario

# %%
class Foo:
    a=33

# %%
f=Foo()
type(f.__dict__)
# Out:
# dict

# %% [markdown]
# En cambio el diccionario de los atributos de clase no es un diccionario ordinario, sino un objeto de tipo types.Napp...

# %%
import types

# %%
types.MappingProxyType is type(Foo.__dict__)
# Out:
# True

# %% [markdown]
# A diferencia de un diccionario ordinario, un objeto de tipo MappingProxyType no soporta la asignacion de sus elementos

# %%
f.__dict__.update({'d':66})
Foo.__dict__.update({'e':77})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-6b60d1899033> in <module>
#       1 f.__dict__.update({'d':66})
# ----> 2 Foo.__dict__.update({'e':77})
#
# AttributeError: 'mappingproxy' object has no attribute 'update'

# %% [markdown]
# Si queremos modificar el diccionario de los atributos de clase, debemos utilizar la funcion integrada setattr()

# %%
setattr(Foo,'foo',88)

# %%
'foo' in Foo.__dict__
# Out:
# True

# %%
Foo.foo
# Out:
# 88

# %% [markdown]
# # Atributos ocultos

# %%
class Foo:
    __a=99

# %%
hasattr(Foo,'__a')
# Out:
# False

# %%
Foo.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-a9024014ae1d> in <module>
# ----> 1 Foo.__a
#
# AttributeError: type object 'Foo' has no attribute '__a'

# %% [markdown]
# En realidad el atributo es visible pero tiene otro nombre. De hecho, cuando se asigna un objeto a un atributo de clase que enpieza con dos guiones bajos, python lo modifica automaticamente situando delante un guion bajo seguido del nombre de la clase

# %%
hasattr(Foo,'_Foo__a')
# Out:
# True

# %%
Foo._Foo__a
# Out:
# 99

# %% [markdown]
# Tambien se ocultan los atributos de instancia

# %%
class Foo:
    def __init__(self,a):
        self.__a=a

# %%
f=Foo(100)
f.__a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-18558e4d936b> in <module>
#       1 f=Foo(100)
# ----> 2 f.__a
#
# AttributeError: 'Foo' object has no attribute '__a'

# %%
f._Foo__a
# Out:
# 100

# %% [markdown]
# Por ultimo obsevamos que esta transformacionpuede reservarnos algunas sorpresas

# %%
class Foo:
    _Foo__a=33
    __a='python'

# %%
Foo._Foo__a
# Out:
# 'python'

# %% [markdown]
# # El inicializador
# Un atributo de instancia existe solo desde el momento en que es asignado la siguiente definicion crea una clase Foo y sus atributos de clase

# %%
class Foo:
    a=33
    def mymethod(self):
        self.b=44

# %%
f=Foo()
f.a
# Out:
# 33

# %% [markdown]
# Los metodos son funciones por lo que, como hemos podido ver, las instrucciones se ejecutan solo en tiempo de ejecucion, al llamar al metodo, por este motivo la instancia f todavia no tiene el atributo, puesto quue se crea despues de la llmada a f.mymthod():

# %%
hasattr(f,'b')
# Out:
# False

# %%
f.b
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-af7557a4d0a6> in <module>
# ----> 1 f.b
#
# AttributeError: 'Foo' object has no attribute 'b'

# %%
f.mymethod()

# %%
f.b
# Out:
# 44

# %% [markdown]
# A menudo se necesita que algunos atributos de instancia esten disponibles de inmediato, por que tienen que ser utilizado por varios metodos y ser definidos cuando estos metodos son llamados. pora ello se define un metodo especial, indicando con __init__() denominado inicializador, al cual python llama automaticamente despúes de la creación  de la instancia, después de inicializarla.

# %%
class Foo:
    def __init__(self):
        self.a=33

# %%
f=Foo()

# %%
f.a
# Out:
# 33

# %% [markdown]
# cuando un inicializador acepta argumentos, estos se pasan en el momento de la creación de la instancia, listandolos en los artumentos que siguen a la etiqueta de la clase

# %%
from math import pi
class Circle:
    def __init__(self,r=1):
        self.radius=0 if r<0 else r
    def area(self):
        return pi*self.radius**2

# %%
c=Circle(3)
c.area()
# Out:
# 28.274333882308138

# %%
# Se pueden crear metodos (funciones) para la clase

class cuadrado:
    #atributos comunes
    _dimension = '2D'
    _vertices = 4

    def __init__(self, lado, color):
        #atributos independientes
        self._lado = lado
        self._color = color
        self._area = lado**2


    # se pueden crear nuevos metodos para la clase
    # metodos para modificar un objeto
    def lado(self, nuevo_lado):
        self._lado = nuevo_lado
        print("se modifico la medida del lado a {}".format(self._lado))

    # metodos que permiten la interaccion entre objetos de la misma clase
    def suma_areas(cuadrado1, cuadrado2):
        suma = cuadrado1._area + cuadrado2._area
        print("La suma de las areas de los cuadrados es {} ".format(
            suma))

# %%
class cuadrado:
    #atributos comunes
    _dimension = '2D'
    _vertices = 4

    def __init__(self, lado, color):
        #atributos independientes
        self._lado = lado
        self._color = color
        self._area = lado**2


    # se pueden crear nuevos metodos para la clase
    # metodos para modificar un objeto
    def lado(self, nuevo_lado):
        self._lado = nuevo_lado
        print("se modifico la medida del lado a {}".format(self._lado))

    # metodos que permiten la interaccion entre objetos de la misma clase
    def suma_areas(cuadrado1, cuadrado2):
        suma = cuadrado1._area + cuadrado2._area
        print("La suma de las areas de los cuadrados es {} ".format(
            suma))

    def __str__(self):
        return "dimension: {}, vertices: {}, color: {}, lado: {}, area: {}".format(
                self._dimension,self._vertices, self._color, self._lado,
                self._area)

# %%
class auto:

    ruedas = 4
    puertas = 4
    estado = None

    def __init__(self, color_auto, marca_auto, ejes_auto, cilindros_auto):
        self.color = color_auto
        self.marca = marca_auto
        self.ejes = ejes_auto
        self.cilindros = cilindros_auto

    def iniciar_recorrido(self):
        print("El auto se ha encendido")
        self.estado = "Encendido"

# %% [markdown]
# # Un primer vistazo a la sobrecarga

# %%
22+33
# Out:
# 55

# %%
'python'*3
# Out:
# 'pythonpythonpython'

# %% [markdown]
# Esto es posible por que python sabe como ejecuatar las operaciones con los tipos integrados. Al definir una clase, si se desea efectuar operaciones con sus instancias es necesario indicar el modo de hacerlo. Consideremos por ejemplola clase Circle. si intentamos sumar sus dosninstancias obtenemos un error

# %%
c1=Circle(10)
c2=Circle(20)
c1+c2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-b77bf0c850b7> in <module>
#       1 c1=Circle(10)
#       2 c2=Circle(20)
# ----> 3 c1+c2
#
# TypeError: unsupported operand type(s) for +: 'Circle' and 'Circle'

# %% [markdown]
# Para poder llevar a cabo esta operacion, debemos en primer lugar decir que significado tiene la suma de dichos objetos

# %%
import math
class Circle:
    def __init__(self,r=1):
        self.radius=0 if r<0 else r
    def __add__(self, other):
        return Circle(self.radius+other.radius)
    def area(self):
        return math.pi*self.radius**2

# %%
c1=Circle(20)
c2=Circle(10)
c=c1+c2
c.radius
# Out:
# 30

# %%
c.area()
# Out:
# 2827.4333882308138

# %% [markdown]
# Cunado python encuentra el operador c1+c2 ejecuta automaticamente la llamada a c1.__add__(c2), es decir Cicle.__add__(c1,c2), por tanto el signo + es solo una representación grafica

# %% [markdown]
# Python asocia un método de llamada para cada representación gráfica. c1+c2 en lugar de c1.__mult__(c2)

# %%
import math
class Circle:
    def __init__(self,r=1):
        self.radius=0 if r<0 else r
    def __add__(self,other):
        return Circle(self.radius+other.radius)
    def __mul__(self,other):
        return Circle(self.radius*other.radius)
    def __sub__(self,other):
        return Circle(self.radius-other.radius)
    def area(self):
        return math.pi*self.radius**2

# %%
c1=Circle(10)
c2=Circle(20)
c=c1+c2
c.radius
# Out:
# 30

# %%
c=c1*c2
c.radius
# Out:
# 200

# %% [markdown]
# Este mecanismo denominado sobrecarga, nos permite utilizar los clasicos operadores aritme2ticos para realizar operaciones entre instancias, haciendo que el codigo sea más ligero y facil de leer

# %% [markdown]
# A continuación complete el código para la clase auto: defina métodos para modificar los atributos de los objetos, además defina el método str. Al crear nuevos métodos tome en cuenta que los nombres de los métodos no pueden ser los mismos que los nombres de las variables.

# %%
class auto:

    ruedas = 4
    puertas = 4
    estado = None

    def __init__(self, color_auto, marca_auto, ejes_auto, cilindros_auto):
        self.color = color_auto
        self.marca = marca_auto
        self.ejes = ejes_auto
        self.cilindros = cilindros_auto

    def iniciar_recorrido(self):
        print("El auto se ha encendido")
        self.estado = "Encendido"

# %%
c=(c1+c2)*c1
c.radius
# Out:
# 300

# %% [markdown]
# # La composicion
#
# Un importante concepto de la POO es la denominada composición. Este termino se utiliza para indicar que un objeto se compone de otro objeto, es decir que un atributo de un objeto de tipo A se refiere a un objeto de tipo

# %%
import math
class point:
    def __init__(self,x=0,y=0):
        self.x=x
        self.y=y
    def distance(self):
        return math.sqrt(self.x**2+self.y**2)
    def __str__(self):
        return str((self.x,self.y))

# %% [markdown]
# El método __str__() tiene un significado especial Python lo llama automaticamente en aquellos casos en que se desea obtener una representacio4n de un objeto obj en forma de cadena.
# La función integrada print() llama a su vez a la función str(). Esto significa que la llamda a print(obj) conlleva la llamada a obj.__str__()

# %%
p=point()
print(p)
# Out:
# (0, 0)

# %%
p.distance()
# Out:
# 0.0

# %%
p=point(3,4)
print(p)
# Out:
# (3, 4)

# %%
p.distance()
# Out:
# 5.0

# %% [markdown]
# Volavamos ahora a  nuestra calse cicle que ampliaremos añadiendole un nuevo atributo de instancia, que representa el centro del circulo

# %% [markdown]
# class Circle:
#     def __init__(self,radius=1, center=point()):
#         self.radius=radius
#         self.center=center
#     def area(self):
#         return math.pi*self.radius**2
#     def distance(self):
#         return self.center.distance()
#     def __str__(self):
#         return '<radius: %f, center: %s>' %(self.radius, self.center)

# %%
c=Circle()
print(c)
# Out:
# <radius: 1.000000, center: (0, 0)>

# %%
c=Circle(10,point(3,4))
print(c)
# Out:
# <radius: 10.000000, center: (3, 4)>

# %%
c.distance()
# Out:
# 5.0

# %%
c.area()
# Out:
# 314.1592653589793

# %% [markdown]
# Lo que acabamos de ver es un ejemplo de relacion de composicion, la cual normalmente se manifiesta cuando un objeto tiene a otro objeto.

# %% [markdown]
# # La herencia
# La herencia es el mecanismo principal de reutilización de codigo en la POO, gracia ala cual es posible hacer que una clase herede los atributos de otra, para no tener que escribir el mismo codigo repetidas veces

# %%
import datetime
class Person:
    def __init__(self, name: str, surname:str , birthday:datetime.date):
        self.name=name
        self.surname=surname
        self.birthday=birthday
    def __str__(self):
        return self.name+' '+self.surname
max=Person('Max','Born',datetime.date(1882,12,11))
max.name, max.birthday.year
# Out:
# ('Max', 1882)

# %%
max

# %%
str(max)
# Out:
# 'Max Born'

# %% [markdown]
# Ahora supongamos que queremos definir una clase que modela un tipo de dato que denominamos profesor, el cual representa un profesor genérico

# %%
class Profesor:
    def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
        self.name=name
        self.surname=surname
        self.bithday=birthday
        self.school=school
    def __str__(self):
        return self.name+' '+self.surname+' , at '+self.school
p=Profesor('Max','Born',datetime.date(1882,12,11),'University of Gotingen')
str(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f35d510bc648> in <module>
# ----> 1 class Profesor:
#       2     def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
#       3         self.name=name
#       4         self.surname=surname
#       5         self.bithday=birthday
#
# <ipython-input-2-f35d510bc648> in Profesor()
#       1 class Profesor:
# ----> 2     def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
#       3         self.name=name
#       4         self.surname=surname
#       5         self.bithday=birthday
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# Como podemos ver la clase profesor tiene mucho en comun con la clase Persona, esto es bastante normal, dado que un profesor es una persona. Cuando entre dos clases existe una realción de este tipo, es conveniente utilizar el mecanismo de herencia, para reutilizar el codigo

# %%
class A:
    a=33
class B(A):
    pass

# %% [markdown]
# como podemos ver, la definicion de la class B está vacia. Sin Embargo, puesto que B hereda de A, todo los atributos de A también son de B

# %%
hasattr(B,'a')
# Out:
# True

# %%
B.a
# Out:
# 33

# %%
b=B()
b.a
# Out:
# 33

# %% [markdown]
# Cuando una clase B hereda de una clase A, se dice que A es la clase base y B es la clase derivada.
# Por tanto utilizando el mecanismo de herencia podemos hacer que la clase Profesor herede de la clase Persona

# %%
class Profesor(Person):
    def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
        self.school=school
        super.__init__(self,name,surname,birthday)
    def __str__(self):
        return super.__str__(self)+', at'+self.school
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-01da61c75070> in <module>
# ----> 1 class Profesor(Person):
#       2     def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
#       3         self.school=school
#       4         super.__init__(self,name,surname,birthday)
#       5     def __str__(self):
#
# NameError: name 'Person' is not defined

# %%
maxi=Profesor('Max','Born',datetime.date(1882,12,11),'University of Gotingen')
str(maxi)
# Out:
# 'Max Born, atUniversity of Gotingen'

# %%
print(maxi.birthday)
# Out:
# 1882-12-11

# %%
Profesor.__base__
# Out:
# __main__.Person

# %% [markdown]
# En esta relacion de herencia Person es la clase base y Profesor es la clase derivada

# %% [markdown]
# # La clase integrada super
#
# En el ejemplo anterior hemos realizado las llamdas a Person.__init__() y a Person.__str__ podemos obtener el mismo resultado llamando a la clase integrada super

# %%
import datetime
class Person:
    def __init__(self, name: str, surname:str , birthday:datetime.date):
        self.name=name
        self.surname=surname
        self.birthday=birthday
    def __str__(self):
        return self.name+' '+self.surname

# %%
class Profesor(Person):
    def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
        self.school=school
        super(Profesor,self).__init__(name,surname,birthday)
    def __str__(self):
        return super(Profesor,self).__str__()+', at'+self.school

# %%
class Profesor(Person):
    def __init__(self,name:str,surname:str,birthday:datetime.date,school:str):
        self.school=school
        super().__init__(name,surname,birthday)
    def __str__(self):
        return super().__str__()+', at'+self.school

# %%
david=Profesor('David','Hilbert',datetime.date(1882,12,11),'University of Gotingen')
print(david)
# Out:
# David Hilbert, atUniversity of Gotingen

# %%
class A:
    def mymethod(self,arg):
        print('A.mymethod():', arg)

# %%
mysuper=super

# %%
class B(A):
    def mymethod(self,arg):
        mysuper().mymethod(arg)

# %%
b=B()

# %%
b.mymethod(100)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-67e6bfe4d7f1> in <module>
# ----> 1 b.mymethod(100)
#
# <ipython-input-19-7c0816846f83> in mymethod(self, arg)
#       1 class B(A):
#       2     def mymethod(self,arg):
# ----> 3         mysuper().mymethod(arg)
#
# RuntimeError: super(): __class__ cell not found

# %%
mysuper=super
class B(A):
    def mymethod(self,arg):
        mysuper(__class__,self).mymethod(arg)
b=B()
b.mymethod(100)
# Out:
# A.mymethod(): 100

# %% [markdown]
# # Herencia multiple y orden de resolucion de metodos
# Pyton admite la herencia multiple, es decir una clase puede heredar de mas de una clase

# %%
class A1:
    a1='python1'
class A2:
    a2='python2'
class A3:
    a3='python3'

# %%
class B(A1,A2,A3):
    pass

# %%
b=B()

# %%
b.a1, b.a2, b.a3
# Out:
# ('python1', 'python2', 'python3')

# %% [markdown]
# Ademas el ambito __base__ tambien tiene el atributo __bases__ que es una tupla cuyos elementos son refrencia a las clases  base

# %%
B.__base__
# Out:
# __main__.A1

# %%
B.__bases__
# Out:
# (__main__.A1, __main__.A2, __main__.A3)

# %% [markdown]
# hemos visto como la clase super crea una instancia de un objeto proxy, el cual delega laas llamadas de los metodos de la clase base, evitando asi tener que calificar la clase explicitamente.
# sin embargo acabamos de ver que Python admite la herencia multiple

# %%
class A1:
    def foo(self):
        print('A1.foo()')
class A2:
    def foo(self):
        print('A2.foo()')
class A3:
    def foo(self):
        print('A3.foo()')
class B(A1,A2,A3):
    def foo(self):
        super().foo()

# %%
b=B()

# %%
b.foo()
# Out:
# A1.foo()

# %% [markdown]
# El orden en que se busca los atributos se denomina MRO (Orden de resolución de metodos) y se indica mediante el atributo  __mro__

# %%
B.__mro__
# Out:
# (__main__.B, __main__.A1, __main__.A2, __main__.A3, object)

# %%
class A:
    pass
A.__mro__
# Out:
# (__main__.A, object)

# %% [markdown]
# # Utilizamos super por que es super
#
# volver a escribir todas las llmadas a los metodos de las clases base, en el caso en que su nombre cambie

# %%
class A:
    def foo(self):
        print('Python3')
class B(A):
    def foo(self):
        A.foo(self)
        print("es marabilloso:")
b=B()

# %%
b.foo()
# Out:
# Python3
# es marabilloso:

# %%
class A:
    def foo(self):
        print('Python3')
class B(A):
    def foo(self):
        super().foo()
        print("es marabilloso:")
b=B()

# %%
b.foo()
# Out:
# Python3
# es marabilloso:

# %% [markdown]
# En caso de herencia multiple super es casi una necisidad

# %%
class A:
    def __init__(self):
        print('A.__init__()')
class A1(A):
    def __init__(self):
        A.__init__(self)
        print('A1.__init__()')
class A2(A):
    def __init__(self):
        A.__init__(self)
        print('A2.__init__()')
class A3(A):
    def __init__(self):
        A.__init__(self)
        print('A3.__init__()')
class B(A1,A2):
    def __init__(self):
        A1.__init__(self)
        A2.__init__(self)
        print('B.__init__()')

# %%
b=B()
# Out:
# A.__init__()
# A1.__init__()
# A.__init__()
# A2.__init__()
# B.__init__()

# %% [markdown]
# como podemos ver, el inicializador de la clase base ha sido llamado dos veces, en cambio, si delegamos todas las llamdas a super() el metodo solo se llama una vez

# %%
class A1(A):
    def __init__(self):
        super().__init__()
        print('A1.__init__()')

class A2(A):
    def __init__(self):
        super().__init__()
        print('A2.__init__()')

class B(A1,A2):
    def __init__(self):
        super().__init__()
        print('B.__init__()')

# %%
b=B()
# Out:
# A.__init__()
# A2.__init__()
# A1.__init__()
# B.__init__()

# %% [markdown]
# B.__mro__

# %%
B.__mro__
# Out:
# (__main__.B, __main__.A1, __main__.A2, __main__.A, object)

# %% [markdown]
# Ahora seguimos el flujo de ejecución partiendo de la llamda b=B() esto es lo que ha sucedido:
#
# 1. La instrucción b=B() ha causado la llamda a b.__init__()(en realidad la etiqueta b todavia no ha sido asignada, pero desde el punto de vista logico no cambia nada)
# 2. La primera instrucción  de b.__init__() es super().__init__() es decir super(B,b).__init__. si miramos el MRO  la clase que sigue a B es A1, por lo que super(B,b).__init__() se traduce en A1.__init__(b)
# 3. La primera ejecucio4n ejecutada por A1.__init__(b) es super().__init(), es decir, super(A1,b).__init__(). la clase que sigue a A1 en el MZro de B es A2, por lo que super(A1,b).__init__(0 se traduce en A2.__init__(b).
# 4. La primera instruccio4n ejecutada por A2.__init__(b) es una vez mas, super().__init__(), la cual corresponde a super(A2,b).__init__(), la clase que sigue a A2 en el MRO de B es A, por lo que la llamada a super(A2,b).__init__() se traduce en A__init__(b)
# 5. A.__int__(b) muestra la cadena 'A.__init__()' y despues devuelve el control a A2.__init__()
# 6. A2.__init__() muestra la cadena 'A2.__init__()' y despues devuelve el control a A1.__init__()
# 7. A1.__init__() muestra la cadena 'A1.__init__()' y despues devuelve el control a B.__init__()
# 8. B.__Init__() muestra la cadena 'B.__init__() y despues devuelve el control a su llamador

# %% [markdown]
# # Anular o sobreescribir metodos de la clase base
#
# consideramos la siguiente clase A

# %%
class A:
    def foo(self):
        print('A.foo()')

# %%
# si una clase B que hereda de A no define el metodo B.foo(), entonces como sabemos lo hereda de A

# %%
class B(A):
    pass
b=B()
b.foo()
# Out:
# A.foo()

# %%
# si lo define pero se limita a llamar a A.foo(), entonces la cituación es identica a la anterior

# %%
class B(A):
    def foo(self):
        super().foo()

# %%
b=B()
b.foo()
# Out:
# A.foo()

# %%
# si encambio B.foo() ademas de llmar al metodo de la clase base, ejecuta también el otro codigo, como se muestra por ejemplo. a continuacio4n

# %%
class B(A):
    def foo(self):
        super().foo()
        print('B.foo()')

# %%
b=B()
b.foo()
# Out:
# A.foo()
# B.foo()

# %% [markdown]
# Entonce se dice que B hace overriding del metodo foo(), en otras palabras, B anula el metodo foo() de la clase base.
# En cambio, si la clase B no llama el metodo foo()  de la clase base, se dice que hace overwriting de foo().

# %%
class B(A):
    def foo(self):
        print('B.foo()')

# %%
b=B()
b.foo()
# Out:
# B.foo()

# %% [markdown]
# # Introducción a las clases base abstracta y al módulo abc
#
# supongamos que queremos definir una clase Planeshape que reperesenta una figura generica, caracterizada por tener una area y un perimetro. oviamente para una figura geometrica generica, no podemos implementar los meodos area() y perimetro(), dado que no existe una formula para calcularlos: el area del circulo se calcula de una manera y la del rectangulo de otra, esto no supone ningun problema, por que no queremos implementar estos metodos en Planeshape. En cambio, si queremos que PlaneShape defina una interfaz generica y que sea las clases heredadas de ella las que implementen los metodos area() y perimetro.

# %%
# La solucion podria ser:
class PlaneShape:
    def area(self):
        raise NotImplementedError("El metodo todavia no ha sido implementado")
    def prerimeter(self):
        raise NotImplementedError("El metodo todavia no ha sido implementado")

# %%
s=PlaneShape()
s.area()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-8-f22cdbf4ebdb> in <module>
#       1 s=PlaneShape()
# ----> 2 s.area()
#
# <ipython-input-7-d0eeb7baf319> in area(self)
#       2 class PlaneShape:
#       3     def area(self):
# ----> 4         raise NotImplementedError("El metodo todavia no ha sido implementado")
#       5     def prerimeter(self):
#       6         raise NotImplementedError("El metodo todavia no ha sido implementado")
#
# NotImplementedError: El metodo todavia no ha sido implementado

# %% [markdown]
# ahora todas las figuras geometricas que heredan de Plane shape tiene una interfaz comun, es decir cuentan con metodos area() y perimetro()

# %%
class Rectangle(PlaneShape):
    pass

# %% [markdown]
# hasattr(Rectangle(),'area')

# %% [markdown]
# Las clases derivadas sin embargo debe sobre escribir estos metodos,por que si son llamados genera una excepción

# %%
square=Rectangle()
square.area()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-8d723654d6a7> in <module>
#       1 square=Rectangle()
# ----> 2 square.area()
#
# <ipython-input-7-d0eeb7baf319> in area(self)
#       2 class PlaneShape:
#       3     def area(self):
# ----> 4         raise NotImplementedError("El metodo todavia no ha sido implementado")
#       5     def prerimeter(self):
#       6         raise NotImplementedError("El metodo todavia no ha sido implementado")
#
# NotImplementedError: El metodo todavia no ha sido implementado

# %% [markdown]
# Veamos algunas clase que hereda de PlaneShape e implementa ambos metodos. Este es un ejemplo de un rectangulo

# %%
class Rectangle(PlaneShape):
    def __init__(self,*sides):
        self.sides=sides
        self.length=max(sides)
        self.width=min(sides)
    def area(self):
        return self.length*self.width
    def perimeter(self):
        return sum(self.sides)

# %%
square=Rectangle(10,10,10,10)
square.perimeter()
# Out:
# 40

# %%
square.area()
# Out:
# 100

# %%
# En cambio este es un ejemplo de un circulo

# %%
import math
class Circle(PlaneShape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius**2
    def perimeter(self):
        return 2*math.pi*self.radius

# %%
c=Circle(10)
c.area()
# Out:
# 314.1592653589793

# %% [markdown]
# Una clase de este tipo, que define una interfaz pero no la implementa completamente, se denomina clase base abstracta, los metodos definidos pero no implementados se denominan metods abstractos.
# Lo ideal es que tanto las clases base abstracta como las que heredan de ella y no implementan los metodos abstractos de la clase base no sean instanciables, Asi no nos arriesgamos a llamar a un metodo no implementado. el modulo abc de la libreria estandar nos permite obtener este comportamiento. Para ello debemos definir PlenShape de la siguiente forma:

# %%
class PlaneShape(metaclass=ABCMeta):
    def area(self):
        """ Devuleve el area de la figura geometrica"""
    area=abstractmethod(area)
    def perimeter(self):
        """ Devuleve el perimeter de la figura geometrica"""
    perimeter=abstractmethod(perimeter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e4064fb93b44> in <module>
# ----> 1 class PlaneShape(metaclass=ABCMeta):
#       2     def area(self):
#       3         """ Devuleve el area de la figura geometrica"""
#       4     area=abstractmethod(area)
#       5     def perimeter(self):
#
# NameError: name 'ABCMeta' is not defined

# %% [markdown]
# # Comportamiento de isintance() e issubclse() con la herencia
#
# Consideremos trs clases una que representa una figura geometrica generica, otra que representa un cuadrilatero y la tercera un cuadrado y supongamos que estan vinculadas mediante uan relacio4n de herencia

# %%
class Shape:

class Rectangle(Shape):

class Square(Rectangle):
# Out:
#   File "<ipython-input-24-6b88fb1bd1ee>", line 3
#     class Rectangle(Shape):
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# Hemos visto que el atributo __bases__ de una clase es una tupla que contiene sus clases ase, por lo que podriamos pensar en utilizarlo para comprobar si una clase es derivada de otra.

# %%
Rectangle in Square.__bases__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-990f0e9cbff2> in <module>
# ----> 1 Rectangle in Square.__bases__
#
# NameError: name 'Square' is not defined

# %%
# sin embargo con esta prueba no podemos decubrir lajerarquia de herencia
Shape in Square.__bases__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-204222343961> in <module>
#       1 # sin embargo con esta prueba no podemos decubrir lajerarquia de herencia
# ----> 2 Shape in Square.__bases__
#
# NameError: name 'Shape' is not defined

# %%
# podriamos pensar en hacerlo comprobando la pertenencia de Shape en Square.__mro__

# %%
Shape in Square.__mro__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-9bee036436fa> in <module>
# ----> 1 Shape in Square.__mro__
#
# NameError: name 'Shape' is not defined

# %%
# El modo correcto de realizar esta prueba es explicitamente, utilizando una denominada funcion integrada denominada issubclass()

# %%
issubclass(Square,Retangle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-fcf9555e8fd2> in <module>
# ----> 1 issubclass(Square,Retangle)
#
# NameError: name 'Square' is not defined

# %%
issubclass(Square,Shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0a51780af559> in <module>
# ----> 1 issubclass(Square,Shape)
#
# NameError: name 'Square' is not defined

# %%
# observamos que una clase se considera subclase de si misma

# %%
issubclass(square,Square)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-59750a0788cf> in <module>
# ----> 1 issubclass(square,Square)
#
# NameError: name 'Square' is not defined

# %% [markdown]
# Si una class B se registra como subclase de una clase abstracta A, la clase A no esta presente en el MRO de B, mientras que issubclass(B,A) devuelve True

# %%
class A(metaclass=ABCMeta):
    pass
class B:
    pass
A.register(B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-20d7f4650676> in <module>
# ----> 1 class A(metaclass=ABCMeta):
#       2     pass
#       3 class B:
#       4     pass
#       5 A.register(B)
#
# NameError: name 'ABCMeta' is not defined

# %%
issubclass(B,A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-882a54bbf757> in <module>
# ----> 1 issubclass(B,A)
#
# NameError: name 'B' is not defined

# %%
A in B.__mro__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1476294a5b05> in <module>
# ----> 1 A in B.__mro__
#
# NameError: name 'A' is not defined

# %% [markdown]
# En cambio la funcion isintance() se utiliza siempre que queramos saber si un objeto es instancia de una determinada clase. De hecho, tanto el arbitro.__class__ como la clase integrada type no muetran la jerarqquia de herencia, mientras que isinstace() si:

# %%
Square().__class__ is Sahpe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-a7271018b7af> in <module>
# ----> 1 Square().__class__ is Sahpe
#
# NameError: name 'Square' is not defined

# %%
type(Square()) is Shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-fd9e9984bf38> in <module>
# ----> 1 type(Square()) is Shape
#
# NameError: name 'Square' is not defined

# %% [markdown]
# # Los Decoradores
#
# Recordemos que en la seccion sobre las clases abstractas definimos la clase PlaneShape

# %%
from abc import ABCMeta, abstractmethod

# %%
class PlaneShape(metaclass=ABCMeta):
    def area(self):
        area=abstractmethod(area)
    def perimeter(self):
        perimeter=abstarctmethod(perimeter)

# %% [markdown]
# Basicamente hemos utilizado la funcion abc.astarctmethod() para decorar metodos, es decir, le hemos pasado el metodo, ha cumplido las acciones en el para modificar su comportamiento y despues lo ha devuelto en una version modificada que nosotros habiamos reasignado a la misma etiqueta. En este caso, las etiquetas primero y despues la decoracion hace referencia al mismo objeto.

# %%
class PlaneShape(metaclass=ABCMeta):
    def area():
        pass
    print(id(area))
    area=abstractmethod(area)
    print(id(area))
    def perimeter(self):
        pass
    print(id(perimeter))
    area=abstractmethod(area)
    print(id(perimeter))
# Out:
# 140716098239648
# 140716098239648
# 140716098544400
# 140716098544400

# %% [markdown]
# Todavia podemos aclarar un poco mas el concepto de decorador con un ejemplo. Considersamos la siguiente funcion

# %%
def mydecorator(func):
    func.lang="python"
    return func

# %% [markdown]
# Esta toma un objeto como argumento, lo decora, es decir, le añade algo (el atributo lang). y luego lo devuleve. podemos utilizar esta funcion como decorador de manera identica a lo que hemos visto con abstractmethod

# %%
def foo():
    pass

# %%
id(foo)
# Out:
# 140716097575664

# %%
hasattr(foo,'lang')
# Out:
# False

# %% [markdown]
# si la pasamos a mydecorador() y despues asignamos el objeto devuelto de nuevo  a la etiqueta foo. el resultado es que foo tiene un nuevo atributo inyectado por mydecorator():

# %%
foo=mydecorator(foo)
id(foo)
# Out:
# 140716097575664

# %%
hasattr(foo,'lang')
# Out:
# True

# %%
foo.lang
# Out:
# 'python'

# %% [markdown]
# Esta operación se denomina decoración, precisamente por el hecho de que tiene el efecto de decorar un objeto con nuevas y distintas funcionalidades. una función o una clase utilizada para un objeto se denomina decorador(decorator) concretamente cuando el objeto a decorar es una funcio4n como en nuestro caso, este proceso se denomina decoracio4n de función y el decorador se denomina decorador de función, Analogaamente, cuando el objeto a decorar es una clase, el proceso se denomina decoración de clase y el decorador, deorador de clase.
# Python tiene una sintaxis especial para realizar de manera concisa una decoración . De hecho dado un decorador mydecorator, si se desea decorar con el una funcion y una clase basta con escribir @mydecorator en la linea que precede la a la definicion de la función de la clase.

# %%
@mydecorator
def foo():
    pass

# %%
hasattr(foo,'lang')
# Out:
# True

# %%
foo.lang
# Out:
# 'python'

# %% [markdown]
# Asi, volviendo a la definición de la clase base abstracta, el siguiente ejemplo

# %%
class PlaneSahape(metaclass=ABCMeta):
    def area(self):
        pass
        area=abstractmethod(area)
    def perimeter(self):
        pass
        area=abstractmethod(area)

# %% [markdown]
# se escribe abitualmente de manera concisa utilizando la sintaxis de los decoradores

# %%
class PlaneShape(metaclass=ABCMeta):
    @abstractmethod
    def area(self):
        pass
    @abstarctmethd
    def perimeter(self):
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-158fbe0c17a2> in <module>
# ----> 1 class PlaneShape(metaclass=ABCMeta):
#       2     @abstractmethod
#       3     def area(self):
#       4         pass
#       5     @abstarctmethd
#
# <ipython-input-60-158fbe0c17a2> in PlaneShape()
#       3     def area(self):
#       4         pass
# ----> 5     @abstarctmethd
#       6     def perimeter(self):
#       7         pass
#
# NameError: name 'abstarctmethd' is not defined

# %% [markdown]
# Los decoradores tambien pueden ser aplicados en cascada. En este caso, cada uno de ellos se indica de una linea distinta

# %%
def mydecorator1(obj):
    obj.lang='Python'
    return obj
def mydecorator2(obj):
    obj.version='3.x'
    return obj
@mydecorator1
@mydecorator2
def foo():
    pass

# %%
foo.lang
# Out:
# 'Python'

# %%
foo.version
# Out:
# '3.x'

# %% [markdown]
# # La funcion functools.wraps()
#
# Un decorador devuelve una funcion distinta a la que toma como argumento y realiza la llamada a la funcion a decorar dentro de esta ultima. por ejemplo

# %%
def mydecorator(f):
    def mywrapper(*args,**kwargs):
        """ wrapper de la funcion a decorar"""
        print("Ejecuto acciones antes de llamar",f.__name__)
        result=f(*args,**kwargs)
        print("ejecuto otras acciones despues de haber llamado",f.__name__)
        return result
    return mywrapper

# %% [markdown]
# La funcion mywrapper() es una especie de envoltorio de la función original en el sentido que cubre dicha función con codigo añadido. las funcione de este tipo se denominan envoltura (wapper) esto es lo que ocurre cuando decoramos una funcion con mydecorator

# %%
@mydecorator
def foo(a,b):
    return a+b

# %%
foo(1,2)
# Out:
# Ejecuto acciones antes de llamar foo
# ejecuto otras acciones despues de haber llamado foo
# 3

# %% [markdown]
# Esta implementación de decorador tiene una grave inconveniente de que sobre escribe los metadatos de la función original, como el nombre y la cadena de documentacion

# %%
foo.__name__
# Out:
# 'mywrapper'

# %%
foo.__doc__
# Out:
# ' wrapper de la funcion a decorar'

# %% [markdown]
# El problema se resuelve decorando la envoltura con la funcion functools.wraper() de la libreria estandar

# %%
import functools
def mydecorator(f):
    @functools.wraps(f)
    def mywrapper(*args,**kwargs):
        print("Ejecuto otras acciones tras haber llamado a ",f.__name__)
        result=f(*args, **kwargs)
        print("Ejecuto otras acciones tras haber llamado a" , f.__name__)
        return result
    return mywrapper

# %%
@mydecorator
def foo(a,b):
    """ Operacion de suma"""
    return a+b

# %%
foo(2,3)
# Out:
# Ejecuto otras acciones tras haber llamado a  foo
# Ejecuto otras acciones tras haber llamado a foo
# 5

# %%
foo.__name__
# Out:
# 'foo'

# %%
foo.__doc__
# Out:
# ' Operacion de suma'

# %%
# El atributo __wrapped__ de foo() se refiere a la función original

# %%
f=foo.__wrapped__

# %%
f(3,4)
# Out:
# 7

# %% [markdown]
# # Decoradores que aceptan argumentos
#
# Hemos comentado que la sintaxis de los decoradores permite escribir este codigo

# %%
def foo():
    pass
foo=myfunction(x,y)(foo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-1db46fbc0cd7> in <module>
#       1 def foo():
#       2     pass
# ----> 3 foo=myfunction(x,y)(foo)
#
# NameError: name 'myfunction' is not defined

# %% [markdown]
# # Aplicación de la programación orientada a objetos

# %%
class Item:
    all=[]
    Item.all.append(self)
    def __init__(self,name,price,quality):
        play_rate=0.8
        assert price>=0, f"price {price} is not grender that or equal to zero"

        assert quantity>=0, f"quantity {quantity=0} is not grender that or equal to zero"
        self.name=name
        self.price=price
        self.quantity=quantity
    def caculate_total_price(self,x,y):
        return x*y
    def apply_discount(self):
        self.price=self.price*Item.play_rate
    def __repr__(self):
        return f"Item {self.name} , {self.price} , {self.quality}"
