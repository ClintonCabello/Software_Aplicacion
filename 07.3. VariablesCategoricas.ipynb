# %% [markdown]
# # Ejemplo de Varibles Categoricos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Definición de las variables:
#-------------------------
# loan_purpose: propósito/intención de uso del préstamo
# householder: si el prestamista es dueño o arrienda la propiedad que habita.
# market: el mercado de riesgo asignado al prestatario (basado en su situación financiera)

data = pd.read_csv('/content/drive/MyDrive/CLASES 2022-I/APLICACION DE SOFTWARE/Clase07/ingenieria-de-variables-master/loan.csv')
data.head()
# Out:
#    customer_id  disbursed_amount  interest market    employment time_employed  \
# 0            0           23201.5   15.4840      C       Teacher     <=5 years
# 1            1            7425.0   11.2032      B    Accountant     <=5 years
# 2            2           11150.0    8.5100      A  Statistician     <=5 years
# 3            3            7600.0    5.8656      A         Other     <=5 years
# 4            4           31960.0   18.7392      E    Bus driver      >5 years
#
#   householder    income date_issued  target        loan_purpose  \
# 0        RENT   84600.0  2013-06-11       0  Debt consolidation
# 1       OWNER  102000.0  2014-05-08       0        Car purchase
# 2        RENT   69840.0  2013-10-26       0  Debt consolidation
# 3        RENT  100386.0  2015-08-20       0  Debt consolidation
# 4        RENT   95040.0  2014-07-22       0  Debt consolidation
#
#    number_open_accounts date_last_payment  number_credit_lines_12
# 0                   4.0        2016-01-14                     NaN
# 1                  13.0        2016-01-25                     NaN
# 2                   8.0        2014-09-26                     NaN
# 3                  20.0        2016-01-26                     NaN
# 4                  14.0        2016-01-11                     NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Examinemos los valores de la variable householder

# esta variable indica si el prestamista posee
# o arrienda la propiedad que habita

data['householder'].unique()
# Out:
# array(['RENT', 'OWNER', 'MORTGAGE'], dtype=object)

# %%
# Creemos un gráfico de barras, con el número de préstamistas
# por cada una de las categorías de householder

# El siguiente código cuenta el número de observaciones (prestamistas)
# en cada una de las categorías y crea un gráfico de barras.

fig = data['householder'].value_counts().plot.bar()
fig.set_title('Tipo de propietario')
fig.set_ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %% [markdown]
# La mayoría de los prestamistas son dueños de sus casas pero todavia pagan una hipoteca (MORTGAGE) o arriendan la propiedad en la que viven (RENT). Algunos pocos prestamistas son dueños de su casa completamente (OWN).

# %%
data['loan_purpose'].value_counts()
# Out:
# Debt consolidation    8214
# Other                  880
# Home improvements      615
# Car purchase            90
# Health                  87
# Holidays                48
# Moving home             47
# Wedding                 19
# Name: loan_purpose, dtype: int64

# %%
# La variable "loan_purpose" es otra variable categórica
# que indica el propósito/intención de uso del préstamo
# por ejemplo para hacer arreglos en la casa o consolidar otras deudas.

data['loan_purpose'].unique()
# Out:
# array(['Debt consolidation', 'Car purchase', 'Other', 'Home improvements',
#        'Moving home', 'Health', 'Holidays', 'Wedding'], dtype=object)

# %% [markdown]
# Exploremos algunos valores:
# - 'Debt_consolidation': el préstamo se va a usar consolidar otras deudas previamente adquiridas
# - 'Car purchase': comprar un vehículo
# - 'Home_improvements': para mejoras/reparaciones en la casa
#
# Esto nos da una idea de la intención de uso del préstamo.

# %%
# Creemos un gráfico de barras, con el número de préstamistas
# por cada una de las categorías

# El siguiente código cuenta el número de observaciones (prestamistas)
# en cada una de las categorías y crea un gráfico de barras.

fig = data['loan_purpose'].value_counts().plot.bar()
fig.set_title('Propósito del préstamo')
fig.set_ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %% [markdown]
# La mayoría de los prestamistas tienen la intención de usar el préstamo para consolidar deudas previamente adquiridas 'Debt consolidation' . Esto es bastante común, ya que los prestamistas prefieren consolidar todas sus deudas en una sola, en este caso usando el préstamo que toman de la empresa de peer to peer. El préstamo usualmente les da la facilidad de ya sea tasas de interés más bajas comparadas con las tarjetas de crédito y por ejemplo plazos más largos para pagar.

# %%
# Miremos otra variable categórica, "market",
# que representa el mercado de riesgo o la banda de riesgo
# asignada al prestatario

data['market'].unique()
# Out:
# array(['C', 'B', 'A', 'E', 'D'], dtype=object)

# %%
# Creemos un gráfico de barras, con el número de préstamistas
# por cada una de las categorías

fig = data['market'].value_counts().plot.bar()
fig.set_title('Estado del préstamo')
fig.set_ylabel('Número de clientes')
# Out:
# Text(0, 0.5, 'Número de clientes')

# %% [markdown]
# La mayoría de los clientes se asignan a los mercados B y C. A son los clientes de menor riesgo, y E los clientes de mayor riesgo. Cuanto más alto es el riesgo, más probable es que el cliente incumpla con los pagos, por lo que las compañías financieras cobran tasas de interés más altas por esos préstamos.

# %%
# Para terminar,  miremos a una variable que es numérica
# pero cuyos valores no tienen un significado real, se usan más como identificadores

data['customer_id'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: customer_id, dtype: int64

# %% [markdown]
# Cada id representa un cliente. Este número es asignado para identificar
# el cliente si se necesita, al mismo tiempo, que se asegura confidencialidad y protección de los datos.

# %%
# La variable tiene tantos valores distintos (ids) como clientes
# en este caso 10,000,

# recuerda que solamente cargamos 10,000 filas/clientes del total de los datos
# del conjunto de datos inicial.

len(data['customer_id'].unique())
# Out:
# 10000

# %%
import pandas as pd

# %%
dfn=pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTWdlshOR1Y6EO6GcX167ihiEiWRiPbtZaiL4QYRoV2G0GjxJe2mLncRXQQlw9f_SRizjwspjDIK18W/pub?gid=1043610645&single=true&output=csv')
dfn
# Out:
#                                                   Name  \
# 0    Joseph M. Acaba,2004,19,Active,5/17/1967,"Ingl...
# 1    James C. Adamson,1984,10,Retired,3/3/1946,"War...
# 2    Dominic A. Antonelli,2000,18,Active,8/23/1967,...
# 3    Jeffrey S. Ashby,1995,15,Retired,6/1/1954,"Dal...
# 4    James P. Bagian,1980,9,Retired,2/22/1952,"Phil...
# ..                                                 ...
# 115  Peggy A. Whitson,1996,16,Active,2/9/1960,"Mt. ...
# 116  Peter J. K. Wisoff,1990,13,Retired,8/16/1958,"...
# 117  Alfred M. Worden,1966,5,Retired,2/7/1932,"Jack...
# 118  John W. Young,1962,2,Retired,9/24/1930,"San Fr...
# 119  George D. Zamka,1998,17,Retired,6/29/1962,"Jer...
#
#                            Year                                     Group  \
# 0                       Geology                                   Geology
# 1                   Engineering                     Aerospace Engineering
# 2    Aeronautics & Astronautics                Aeronautics & Astronautics
# 3        Mechanical Engineering                          Aviation Systems
# 4        Mechanical Engineering                                  Medicine
# ..                          ...                                       ...
# 115         Chemistry & Biology                              Biochemistry
# 116                     Physics                           Applied Physics
# 117            Military Science  Aeronautical & Astronautical Engineering
# 118                         NaN                                       NaN
# 119                 Mathematics                    Engineering Management
#
#         Status                 Birth Date  Birth Place   Gender Alma Mater  \
# 0          NaN                        NaN          2.0   3307.0          2
# 1      Colonel          US Army (Retired)          2.0    334.0          0
# 2    Commander                    US Navy          2.0    579.0          0
# 3      Captain          US Navy (Retired)          3.0    655.0          0
# 4          NaN                        NaN          2.0    337.0          0
# ..         ...                        ...          ...      ...        ...
# 115        NaN                        NaN          3.0  11698.0          7
# 116        NaN                        NaN          4.0   1064.0          3
# 117    Colonel     US Air Force (Retired)          1.0    295.0          1
# 118        NaN                        NaN          NaN      NaN        NaN
# 119    Colonel  US Marine Corps (Retired)          2.0    692.0          0
#
#      Undergraduate Major          Graduate Major  ... Unnamed: 277  \
# 0                   13.0     STS-119 (Discovery)  ...          NaN
# 1                    0.0       STS-28 (Columbia)  ...          NaN
# 2                    0.0     STS-119 (Discovery)  ...          NaN
# 3                    0.0       STS-93 (Columbia)  ...          NaN
# 4                    0.0      STS-29 (Discovery)  ...          NaN
# ..                   ...                     ...  ...          ...
# 115                 46.0  STS-111/113 (Endeavor)  ...          NaN
# 116                 20.0       STS-57 (Endeavor)  ...          NaN
# 117                  0.5               Apollo 15  ...          NaN
# 118                  NaN                     NaN  ...          NaN
# 119                  0.0     STS-120 (Discovery)  ...          NaN
#
#     Unnamed: 278 Unnamed: 279 Unnamed: 280 Unnamed: 281 Unnamed: 282  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 115          NaN          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN          NaN
# 118          NaN          NaN          NaN          NaN          NaN
# 119          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 283 Unnamed: 284 Unnamed: 285 Unnamed: 286
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 115          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN
# 118          NaN          NaN          NaN          NaN
# 119          NaN          NaN          NaN          NaN
#
# [120 rows x 287 columns]

# %%
dfn.describe()
# Out:
#        Birth Place        Gender  Undergraduate Major  Unnamed: 28  \
# count    91.000000     91.000000            89.000000    62.000000
# mean      2.307692   1270.989011             8.241573   230.048387
# std       1.235514   1965.226385            12.291930   780.518248
# min       0.000000      0.000000             0.000000     0.000000
# 25%       1.000000    298.000000             0.000000     0.000000
# 50%       2.000000    562.000000             0.000000     1.500000
# 75%       3.000000   1002.500000            13.000000    21.250000
# max       5.000000  11698.000000            58.000000  4376.000000
#
#        Unnamed: 184  Unnamed: 196  Unnamed: 197  Unnamed: 198  Unnamed: 218  \
# count      4.000000      4.000000      4.000000      4.000000      3.000000
# mean     499.750000   1543.500000    168.500000      3.500000   1306.666667
# std      976.836518   2371.711126    335.667991      6.350853   2260.615034
# min        8.000000      1.000000      0.000000      0.000000      1.000000
# 25%       11.000000    337.750000      0.000000      0.000000      1.500000
# 50%       13.000000    547.500000      1.000000      0.500000      2.000000
# 75%      501.750000   1753.250000    169.500000      4.000000   1959.500000
# max     1965.000000   5078.000000    672.000000     13.000000   3917.000000
#
#        Unnamed: 232  ...  Unnamed: 261  Unnamed: 262  Unnamed: 265  \
# count           0.0  ...           1.0           1.0           0.0
# mean            NaN  ...           6.0          43.0           NaN
# std             NaN  ...           NaN           NaN           NaN
# min             NaN  ...           6.0          43.0           NaN
# 25%             NaN  ...           6.0          43.0           NaN
# 50%             NaN  ...           6.0          43.0           NaN
# 75%             NaN  ...           6.0          43.0           NaN
# max             NaN  ...           6.0          43.0           NaN
#
#        Unnamed: 267  Unnamed: 268  Unnamed: 275  Unnamed: 279  Unnamed: 280  \
# count           1.0           1.0           0.0           1.0           1.0
# mean         1962.0           2.0           NaN           2.0          97.0
# std             NaN           NaN           NaN           NaN           NaN
# min          1962.0           2.0           NaN           2.0          97.0
# 25%          1962.0           2.0           NaN           2.0          97.0
# 50%          1962.0           2.0           NaN           2.0          97.0
# 75%          1962.0           2.0           NaN           2.0          97.0
# max          1962.0           2.0           NaN           2.0          97.0
#
#        Unnamed: 281  Unnamed: 282
# count           1.0           1.0
# mean            1.0           0.5
# std             NaN           NaN
# min             1.0           0.5
# 25%             1.0           0.5
# 50%             1.0           0.5
# 75%             1.0           0.5
# max             1.0           0.5
#
# [8 rows x 29 columns]

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Columns: 287 entries, Name to Unnamed: 286
# dtypes: float64(29), object(258)
# memory usage: 269.2+ KB

# %%
dfn.shape
# Out:
# (120, 287)

# %%
dfn.tail()
# Out:
#                                                   Name                 Year  \
# 115  Peggy A. Whitson,1996,16,Active,2/9/1960,"Mt. ...  Chemistry & Biology
# 116  Peter J. K. Wisoff,1990,13,Retired,8/16/1958,"...              Physics
# 117  Alfred M. Worden,1966,5,Retired,2/7/1932,"Jack...     Military Science
# 118  John W. Young,1962,2,Retired,9/24/1930,"San Fr...                  NaN
# 119  George D. Zamka,1998,17,Retired,6/29/1962,"Jer...          Mathematics
#
#                                         Group   Status  \
# 115                              Biochemistry      NaN
# 116                           Applied Physics      NaN
# 117  Aeronautical & Astronautical Engineering  Colonel
# 118                                       NaN      NaN
# 119                    Engineering Management  Colonel
#
#                     Birth Date  Birth Place   Gender Alma Mater  \
# 115                        NaN          3.0  11698.0          7
# 116                        NaN          4.0   1064.0          3
# 117     US Air Force (Retired)          1.0    295.0          1
# 118                        NaN          NaN      NaN        NaN
# 119  US Marine Corps (Retired)          2.0    692.0          0
#
#      Undergraduate Major          Graduate Major  ... Unnamed: 277  \
# 115                 46.0  STS-111/113 (Endeavor)  ...          NaN
# 116                 20.0       STS-57 (Endeavor)  ...          NaN
# 117                  0.5               Apollo 15  ...          NaN
# 118                  NaN                     NaN  ...          NaN
# 119                  0.0     STS-120 (Discovery)  ...          NaN
#
#     Unnamed: 278 Unnamed: 279 Unnamed: 280 Unnamed: 281 Unnamed: 282  \
# 115          NaN          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN          NaN
# 118          NaN          NaN          NaN          NaN          NaN
# 119          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 283 Unnamed: 284 Unnamed: 285 Unnamed: 286
# 115          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN
# 118          NaN          NaN          NaN          NaN
# 119          NaN          NaN          NaN          NaN
#
# [5 rows x 287 columns]

# %% [markdown]
# **Esto es todo por este demo, esperamos lo hayan disfrutado y nos vemos en el siguiente. **
